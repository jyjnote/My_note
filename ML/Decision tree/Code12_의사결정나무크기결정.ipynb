# %% [markdown]
# # Loan 데이터 분류나무

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan.csv')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['job'] = df['job'].replace({'Office':0, 'ProfExe':1, 'Other':2, 'Mgr':3, 'Self':4, 'Sales':5})
df.groupby('job').mean()
# Out:
#             y          loan      mortgage  workyear  delinquency      period  \
# job
# 0    0.180909  18104.440000  67958.616364  8.399091     0.436364  177.157945
# 1    0.204577  18883.011096  92253.009709  8.751040     0.417476  194.267684
# 2    0.232263  17911.422167  62103.232616  9.272503     0.374162  172.503607
# 3    0.279412  18947.905462  80028.710084  9.172269     0.558824  173.443193
# 4    0.403226  23403.201613  85134.940860  7.793011     0.534946  172.465457
# 5    0.414384  16926.616438  76520.465753  8.065068     0.400685  178.711438
#
#       inquire   transact        DTI
# job
# 0    1.017273  21.200909  34.772091
# 1    1.044383  24.070042  33.676685
# 2    1.288740  19.263678  34.464261
# 3    1.477941  22.580882  36.054979
# 4    1.411290  22.432796  36.581478
# 5    1.184932  22.595890  36.410377

# %% [markdown]
# ### 나무 모형

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
X = df.drop(['y'], axis=1)
y = df['y']
xname = X.columns
yname = ['Normal','Bad']

# %% [markdown]
# ### 모든 Alpha 와 Impurity의 계산

# %%
c_tree = DecisionTreeClassifier(random_state=0) 
path = c_tree.cost_complexity_pruning_path(X, y)
path
# path = pd.DataFrame(path)
# path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 9.22845502e-05, 9.44525047e-05, 9.49698793e-05,
#         9.94248146e-05, 1.12750006e-04, 1.13603619e-04, 1.22606617e-04,
#         1.25160921e-04, 1.25160921e-04, 1.25160921e-04, 1.27147602e-04,
#         1.30037321e-04, 1.30037321e-04, 1.33176153e-04, 1.33504983e-04,
#         1.35512576e-04, 1.35512576e-04, 1.35512576e-04, 1.37081009e-04,
#         1.37081009e-04, 1.37162653e-04, 1.37319411e-04, 1.37539474e-04,
#         1.37743236e-04, 1.37743236e-04, 1.37816836e-04, 1.38108603e-04,
#         1.38108603e-04, 1.38245559e-04, 1.38273018e-04, 1.39175078e-04,
#         1.39697236e-04, 1.39862363e-04, 1.39931465e-04, 1.40180232e-04,
#         1.40440306e-04, 1.40616628e-04, 1.40696117e-04, 1.40733939e-04,
#         1.40906112e-04, 1.41108066e-04, 1.41338630e-04, 1.41535357e-04,
#         1.42678004e-04, 1.43041053e-04, 1.43041053e-04, 1.43041053e-04,
#         1.43041053e-04, 1.43041053e-04, 1.43041053e-04, 1.43041053e-04,
#         1.43582875e-04, 1.43711854e-04, 1.58934503e-04, 1.63066800e-04,
#         1.75225290e-04, 1.77725496e-04, 1.81850641e-04, 1.83909925e-04,
#         1.84144804e-04, 1.85635500e-04, 1.88307209e-04, 1.90721404e-04,
#         1.90721404e-04, 1.90721404e-04, 1.90721404e-04, 1.90721404e-04,
#         1.90721404e-04, 1.90721404e-04, 1.90721404e-04, 1.90721404e-04,
#         1.90721404e-04, 1.90721404e-04, 1.90721404e-04, 1.93118912e-04,
#         1.93671411e-04, 1.94694766e-04, 1.95316765e-04, 2.00257474e-04,
#         2.00360328e-04, 2.09071568e-04, 2.14561579e-04, 2.14561579e-04,
#         2.14561579e-04, 2.14561579e-04, 2.14561579e-04, 2.14561579e-04,
#         2.14561579e-04, 2.14561579e-04, 2.14561579e-04, 2.16794065e-04,
#         2.17967319e-04, 2.28865684e-04, 2.28865684e-04, 2.28865684e-04,
#         2.28865684e-04, 2.28865684e-04, 2.28865684e-04, 2.28865684e-04,
#         2.31984266e-04, 2.38401755e-04, 2.38401755e-04, 2.38401755e-04,
#         2.45031108e-04, 2.45213233e-04, 2.45213233e-04, 2.45213233e-04,
#         2.47256677e-04, 2.47937825e-04, 2.47937825e-04, 2.50321842e-04,
#         2.51752253e-04, 2.52034306e-04, 2.53072632e-04, 2.54177600e-04,
#         2.54295205e-04, 2.54295205e-04, 2.54295205e-04, 2.55808867e-04,
#         2.56281505e-04, 2.57473895e-04, 2.57802725e-04, 2.60074641e-04,
#         2.60074641e-04, 2.62371496e-04, 2.63661878e-04, 2.64185821e-04,
#         2.65647669e-04, 2.65838588e-04, 2.66049329e-04, 2.67009965e-04,
#         2.67009965e-04, 2.69253746e-04, 2.70188655e-04, 2.71839945e-04,
#         2.72621428e-04, 2.73255812e-04, 2.74145290e-04, 2.75078948e-04,
#         2.75864888e-04, 2.76546035e-04, 2.77412951e-04, 2.81747528e-04,
#         2.82317867e-04, 2.86082106e-04, 2.86082106e-04, 2.96824974e-04,
#         2.98050649e-04, 3.01504329e-04, 3.06516542e-04, 3.17450531e-04,
#         3.17725174e-04, 3.33762456e-04, 3.37275746e-04, 3.45341970e-04,
#         3.52101053e-04, 3.54183844e-04, 3.57602632e-04, 3.64537956e-04,
#         3.67819850e-04, 3.71741874e-04, 3.81442807e-04, 3.83458311e-04,
#         4.01910470e-04, 4.11144085e-04, 4.24213282e-04, 4.25036271e-04,
#         4.30805994e-04, 4.33457736e-04, 4.39682938e-04, 4.41126603e-04,
#         4.41383820e-04, 4.43794036e-04, 4.46114334e-04, 4.48628756e-04,
#         4.58464913e-04, 4.59942632e-04, 4.61188005e-04, 4.64614547e-04,
#         4.72657392e-04, 4.82763553e-04, 4.90426467e-04, 5.03938668e-04,
#         5.05913618e-04, 5.19275082e-04, 5.20219881e-04, 5.25024454e-04,
#         5.28942617e-04, 5.29231548e-04, 5.34019930e-04, 5.34019930e-04,
#         5.50157895e-04, 5.63405751e-04, 5.86292157e-04, 5.86554344e-04,
#         5.97040916e-04, 6.05966732e-04, 6.28527837e-04, 6.35117780e-04,
#         6.44711973e-04, 6.55623776e-04, 6.66719094e-04, 6.72292948e-04,
#         6.86597053e-04, 6.96835220e-04, 6.99125380e-04, 7.06214112e-04,
#         7.32738235e-04, 7.35889437e-04, 7.59217896e-04, 7.62885615e-04,
#         7.78108560e-04, 7.84682347e-04, 7.94428001e-04, 8.15068813e-04,
#         8.15882242e-04, 8.58246317e-04, 8.98077830e-04, 9.22581865e-04,
#         9.55188341e-04, 9.71582677e-04, 9.72679159e-04, 9.79104532e-04,
#         9.91956823e-04, 9.99333117e-04, 1.00130071e-03, 1.05913628e-03,
#         1.18158515e-03, 1.18309002e-03, 1.27387479e-03, 1.34408020e-03,
#         1.34913627e-03, 1.41347473e-03, 1.43180947e-03, 1.66881228e-03,
#         1.69105976e-03, 1.92237521e-03, 1.97262384e-03, 2.10223369e-03,
#         2.18220564e-03, 2.30368929e-03, 3.29379488e-03, 3.61181574e-03,
#         3.66462334e-03, 3.94719619e-03, 9.26537826e-03, 2.27314680e-02,
#         2.51008158e-02, 9.92722068e-02]),
#  'impurities': array([0.        , 0.00055371, 0.00083706, 0.00112197, 0.00142025,
#         0.001984  , 0.00255202, 0.00279723, 0.00304755, 0.00329787,
#         0.0035482 , 0.00380249, 0.00406257, 0.00432264, 0.00485534,
#         0.00512235, 0.00539338, 0.00566441, 0.00593543, 0.00620959,
#         0.00648375, 0.00730673, 0.00758137, 0.00785645, 0.00813193,
#         0.00840742, 0.00895869, 0.00923491, 0.01006356, 0.01034005,
#         0.01061659, 0.01089494, 0.01117434, 0.01145406, 0.01173393,
#         0.01201429, 0.01229517, 0.0125764 , 0.01285779, 0.01342073,
#         0.01370254, 0.01398476, 0.01426743, 0.01455051, 0.01483586,
#         0.01512194, 0.01526498, 0.01540803, 0.01555107, 0.01569411,
#         0.01583715, 0.01598019, 0.01626736, 0.01655478, 0.01671371,
#         0.01752905, 0.0178795 , 0.0193013 , 0.01984685, 0.02003076,
#         0.0205832 , 0.0211401 , 0.02170503, 0.02189575, 0.02208647,
#         0.02227719, 0.02246791, 0.02265863, 0.02284935, 0.02304008,
#         0.02342152, 0.02361224, 0.02380296, 0.02399368, 0.02437513,
#         0.02592008, 0.02688843, 0.02708313, 0.02845035, 0.0286506 ,
#         0.02965241, 0.03048869, 0.03091782, 0.03113238, 0.03134694,
#         0.0315615 , 0.03177606, 0.03199062, 0.03220518, 0.03241975,
#         0.03263431, 0.03393507, 0.03415304, 0.03438191, 0.03461077,
#         0.03483964, 0.0350685 , 0.03529737, 0.03552623, 0.0357551 ,
#         0.03621907, 0.03693427, 0.03717267, 0.03741108, 0.03765611,
#         0.03790132, 0.03814653, 0.03839175, 0.038639  , 0.03913488,
#         0.03963076, 0.03988108, 0.04063633, 0.04139244, 0.04215165,
#         0.04240583, 0.04266013, 0.04291442, 0.04316872, 0.04342453,
#         0.04701247, 0.04752742, 0.04778522, 0.04804529, 0.04856544,
#         0.04909019, 0.04935385, 0.04988222, 0.05014787, 0.05094538,
#         0.05227563, 0.05254264, 0.05307666, 0.05334591, 0.0536161 ,
#         0.05443162, 0.05715784, 0.0579776 , 0.05907418, 0.05934926,
#         0.05962513, 0.05990167, 0.06017909, 0.06046083, 0.06074315,
#         0.06131532, 0.0616014 , 0.06219505, 0.06279115, 0.06580619,
#         0.06611271, 0.06896976, 0.06928749, 0.06962125, 0.06995853,
#         0.07064921, 0.07100131, 0.0734806 , 0.0738382 , 0.07420274,
#         0.07457056, 0.07903146, 0.07941291, 0.08401441, 0.08602396,
#         0.08725739, 0.08810582, 0.08853085, 0.08982327, 0.09025673,
#         0.09113609, 0.09157722, 0.0920186 , 0.0924624 , 0.09335463,
#         0.09425188, 0.09516881, 0.09562876, 0.09608995, 0.09655456,
#         0.09844519, 0.09892795, 0.09941838, 0.09992232, 0.10042823,
#         0.10094751, 0.10354861, 0.10512368, 0.10618156, 0.1067108 ,
#         0.10724482, 0.10831286, 0.10886301, 0.10942642, 0.11001271,
#         0.11059927, 0.11119631, 0.11240824, 0.11806499, 0.11870011,
#         0.11934482, 0.12000044, 0.12066716, 0.12335634, 0.12404293,
#         0.12473977, 0.12543889, 0.12614511, 0.12907606, 0.13275551,
#         0.13351473, 0.13427761, 0.13505572, 0.1358404 , 0.13663483,
#         0.1374499 , 0.13908166, 0.13993991, 0.14083799, 0.14268315,
#         0.14459353, 0.14556511, 0.14653779, 0.14751689, 0.14850885,
#         0.14950818, 0.15050948, 0.15580517, 0.15698675, 0.15816984,
#         0.16199147, 0.16333555, 0.16468468, 0.16609816, 0.16752997,
#         0.16919878, 0.17088984, 0.17281221, 0.17675746, 0.1851664 ,
#         0.1873486 , 0.19195598, 0.19524978, 0.20247341, 0.20613803,
#         0.21008523, 0.2193506 , 0.24208207, 0.26718289, 0.3664551 ])}

# %%
path = pd.DataFrame(path)
path
# Out:
#      ccp_alphas  impurities
# 0      0.000000    0.000000
# 1      0.000092    0.000554
# 2      0.000094    0.000837
# 3      0.000095    0.001122
# 4      0.000099    0.001420
# ..          ...         ...
# 245    0.003947    0.210085
# 246    0.009265    0.219351
# 247    0.022731    0.242082
# 248    0.025101    0.267183
# 249    0.099272    0.366455
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Alpha 와 Impurity의 관계

# %%
fig, ax = plt.subplots()
ax.plot(path.ccp_alphas, path.impurities, marker='o', drawstyle="steps-post")
ax.set_xlim(0.1, 0)  # decreasing order
plt.show()

# %%
ax.set_xlim(0.1, 0)
ax
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
ax.plot(path.ccp_alphas, path.impurities, marker='o', drawstyle="steps-post")
ax.set_xlim(0.004, 0)  # decreasing order
plt.show(),fig,ax
# Out:
# (None, <Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### 최적의 Alpha를 찾는 방법

# %%
from sklearn.model_selection import GridSearchCV
np.random.seed(0)
g_cv = GridSearchCV(DecisionTreeClassifier(random_state=0),
              param_grid={'ccp_alpha': np.arange(0.000, 0.005, 0.0001)}, cv=10, n_jobs=-1)
g_cv.fit(X, y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'ccp_alpha': array([0.    , 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007,
#        0.0008, 0.0009, 0.001 , 0.0011, 0.0012, 0.0013, 0.0014, 0.0015,
#        0.0016, 0.0017, 0.0018, 0.0019, 0.002 , 0.0021, 0.0022, 0.0023,
#        0.0024, 0.0025, 0.0026, 0.0027, 0.0028, 0.0029, 0.003 , 0.0031,
#        0.0032, 0.0033, 0.0034, 0.0035, 0.0036, 0.0037, 0.0038, 0.0039,
#        0.004 , 0.0041, 0.0042, 0.0043, 0.0044, 0.0045, 0.0046, 0.0047,
#        0.0048, 0.0049])})

# %%
print('selected:',g_cv.best_params_)
print('score   :',g_cv.best_score_)
# Out:
# selected: {'ccp_alpha': 0.0033}
# score   : 0.7390145105252401

# %% [markdown]
# ### Alpha=0.0033 트리

# %%
c_tree = DecisionTreeClassifier(ccp_alpha=0.0033,random_state=0) 
c_tree.fit(X, y)
plt.figure(figsize=(15,10))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=10) 
plt.show()

# %% [markdown]
# ### 하이퍼파라미터 튜닝

# %%
np.random.seed(0)
g_cv = GridSearchCV(DecisionTreeClassifier(random_state=0),
              param_grid={'ccp_alpha': np.arange(0.000, 0.005, 0.0001),
                          'min_impurity_decrease': np.arange(0,0.003,0.0005),
                          'min_samples_split': np.arange(800,1200,200)},
                    cv=10, n_jobs=-1)
g_cv.fit(X, y)

# %%
print('selected:',g_cv.best_params_)
print('score   :',g_cv.best_score_)

# %% [markdown]
# ### Alpha=0.0, min_impurity_decrease=0.001,  min_samples_split=1000  트리

# %%
c_tree = DecisionTreeClassifier(ccp_alpha=0.0,min_impurity_decrease=0.001,min_samples_split=1000,random_state=0) 
c_tree.fit(X, y)
plt.figure(figsize=(15,15))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=9) 
plt.show()
