# %% [markdown]
# # 분류나무 불안정성

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\Desktop\data\sample1.csv')
X = df1.drop('y', axis=1)
y = df1['y']

# %%
sns.scatterplot(data=df1, x='x1', y='x2', hue='y')#, palette="Set2")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
c_tree = DecisionTreeClassifier(max_depth=1, random_state=0)
c_tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=1, random_state=0)

# %% [markdown]
# ### 나무 모형

# %%
# xname = X.columns
xname = ['x1', 'x2']
yname = ['0','1']
plt.figure(figsize=(10,5))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=12) 
plt.show()

# %%
df1 = pd.read_csv(r'C:\Users\hopio\Desktop\yonsei_practice\data\sample1.csv')
X = df1.drop('y', axis=1)
y = df1['y']
y[0]=0

# %%
c_tree = DecisionTreeClassifier(max_depth=1, random_state=0)
c_tree.fit(X, y)
plt.figure(figsize=(10,5))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=12) 
plt.show()

# %%
df1 = pd.read_csv(r'C:\Users\Desktop\data\sample1.csv')
X = df1.drop('y', axis=1)
y = df1['y']
y[0]=0
y[1]=1

# %%
c_tree = DecisionTreeClassifier(max_depth=1, random_state=0)
c_tree.fit(X, y)
plt.figure(figsize=(10,5))
plot_tree(c_tree, feature_names=xname, class_names=yname, filled=True, fontsize=12) 
plt.show()
